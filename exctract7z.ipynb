# %%
# !pip install py7zr
import py7zr
from pathlib import Path

base_dir = Path(".")  

for archive_path in base_dir.glob("*.7z"):
    out_dir = archive_path.with_suffix("")
    out_dir.mkdir(exist_ok=True)

    with py7zr.SevenZipFile(archive_path, mode="r") as archive:
        archive.extractall(path=out_dir)

    print(f"Extracted: {archive_path} -> {out_dir}")
# Out:
# Looking in indexes: https://nexus.iisys.de/repository/ki-awz-pypi-group/simple, https://pypi.org/simple
# ...
#   Using cached texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# ...
#   Using cached pycryptodomex-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# ...
#   Using cached multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 35.4 MB/s  0:00:00
# ...
# Using cached multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# ...
# Using cached pycryptodomex-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
# ...
# Using cached texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# ...
#   Attempting uninstall: brotli
#     Found existing installation: Brotli 1.1.0
#     Uninstalling Brotli-1.1.0:
#       Successfully uninstalled Brotli-1.1.0━━━━━━━━━━━━━━━━━━━━━━━ 1/9 [brotli]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [py7zr]32m8/9 [py7zr]todomex]
# ...
# Extracted: DatasetFinal.7z -> DatasetFinal
